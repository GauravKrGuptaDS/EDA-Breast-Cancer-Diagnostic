# %% [markdown]
# <a href="https://colab.research.google.com/github/GauravKrGuptaDS/EDA-Breast-Cancer-Diagnostic/blob/main/EDA_BreastCancerDiagnostic.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Importing important Libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
# Importing the data
df = pd.read_csv('/content/brca.csv')
df.head()
# Out:
#    Unnamed: 0  x.radius_mean  x.texture_mean  x.perimeter_mean  x.area_mean  \
# 0           1         13.540           14.36             87.46        566.3
# 1           2         13.080           15.71             85.63        520.0
# 2           3          9.504           12.44             60.34        273.9
# 3           4         13.030           18.42             82.61        523.8
# 4           5          8.196           16.84             51.71        201.9
#
#    x.smoothness_mean  x.compactness_mean  x.concavity_mean  \
# 0            0.09779             0.08129           0.06664
# 1            0.10750             0.12700           0.04568
# 2            0.10240             0.06492           0.02956
# 3            0.08983             0.03766           0.02562
# 4            0.08600             0.05943           0.01588
#
#    x.concave_pts_mean  x.symmetry_mean  ...  x.texture_worst  \
# 0            0.047810           0.1885  ...            19.26
# ...

# %%
# Getting the shape of the data
print('Shape : ', df.shape)
# Out:
# Shape :  (569, 32)

# %%
# Getting an idea about the columns
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 569 entries, 0 to 568
# Data columns (total 32 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Unnamed: 0           569 non-null    int64
#  1   x.radius_mean        569 non-null    float64
#  2   x.texture_mean       569 non-null    float64
#  3   x.perimeter_mean     569 non-null    float64
#  4   x.area_mean          569 non-null    float64
#  5   x.smoothness_mean    569 non-null    float64
#  6   x.compactness_mean   569 non-null    float64
#  7   x.concavity_mean     569 non-null    float64
#  8   x.concave_pts_mean   569 non-null    float64
#  9   x.symmetry_mean      569 non-null    float64
#  10  x.fractal_dim_mean   569 non-null    float64
#  11  x.radius_se          569 non-null    float64
#  12  x.texture_se         569 non-null    float64
#  13  x.perimeter_se       569 non-null    float64
#  14  x.area_se            569 non-null    float64
# ...

# %%
# dropping the column 'Unnamed: 0'
df = df.drop('Unnamed: 0', axis = 1)

# %%
# Getting an idea about the columns
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 569 entries, 0 to 568
# Data columns (total 31 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   x.radius_mean        569 non-null    float64
#  1   x.texture_mean       569 non-null    float64
#  2   x.perimeter_mean     569 non-null    float64
#  3   x.area_mean          569 non-null    float64
#  4   x.smoothness_mean    569 non-null    float64
#  5   x.compactness_mean   569 non-null    float64
#  6   x.concavity_mean     569 non-null    float64
#  7   x.concave_pts_mean   569 non-null    float64
#  8   x.symmetry_mean      569 non-null    float64
#  9   x.fractal_dim_mean   569 non-null    float64
#  10  x.radius_se          569 non-null    float64
#  11  x.texture_se         569 non-null    float64
#  12  x.perimeter_se       569 non-null    float64
#  13  x.area_se            569 non-null    float64
#  14  x.smoothness_se      569 non-null    float64
# ...

# %%
# getting an idea about the duplicate rows in the data
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
# np.int64(0) means that there are no duplicate rows in the data

# %%
# getting an idea about the NULL values in the data
df.isnull().sum().any()
# Out:
# np.False_

# %%
# np.False_ means that there are no NULL values in the data

# %%
df.y.value_counts()
# Out:
# y
# B    357
# M    212
# Name: count, dtype: int64

# %%
# Box plot
plt.figure(figsize = (18, 5))

plt.subplot(151)
df.boxplot('x.radius_mean')

plt.subplot(152)
df.boxplot('x.texture_mean')

plt.subplot(153)
df.boxplot('x.perimeter_mean')

plt.subplot(154)
df.boxplot('x.area_mean')

plt.subplot(155)
df.boxplot('x.smoothness_mean')

plt.show()

# %%
'''
Conclusions ->
1. radius_mean has more than 10 outliers on the higher side
2. texture_mean has 7 outliers on the higher side
3. perimeter_mean has more than 10 outliers on the higher side
4. area_mean has has more than 15 outliers on the higher side
5. smoothness_mean have 5 outliers on the higher side and one outlier on the lower side
'''
# Out:
# '\nConclusions ->\n1. radius_mean has more than 10 outliers on the higher side\n2. texture_mean has 7 outliers on the higher side\n3. perimeter_mean has more than 10 outliers on the higher side\n4. area_mean has has more than 15 outliers on the higher side\n5. smoothness_mean have 5 outliers on the higher side and one outlier on the lower side\n'

# %%
# Box plot
plt.figure(figsize = (18, 5))

plt.subplot(151)
df.boxplot('x.compactness_mean')

plt.subplot(152)
df.boxplot('x.concavity_mean')

plt.subplot(153)
df.boxplot('x.concave_pts_mean')

plt.subplot(154)
df.boxplot('x.symmetry_mean')

plt.subplot(155)
df.boxplot('x.fractal_dim_mean')

plt.show()

# %%
'''
Conclusions ->
1. compactness_mean has more than 10 outliers on the higher side
2. concavity_mean has more than 10 outliers on the higher side
3. concave_pts_mean has 10 outliers on the higher side
4. symmetry_mean have more than 10 outliers on the higher side and 1 outlier on the lower side
5. fractal_dim_mean has more than 10 outliers on the higher side
'''
# Out:
# '\nConclusions ->\n1. compactness_mean has more than 10 outliers on the higher side\n2. concavity_mean has more than 10 outliers on the higher side\n3. concave_pts_mean has 10 outliers on the higher side\n4. symmetry_mean have more than 10 outliers on the higher side and 1 outlier on the lower side\n5. fractal_dim_mean has more than 10 outliers on the higher side\n'

# %%
# Box plot
plt.figure(figsize = (18, 5))

plt.subplot(151)
df.boxplot('x.radius_se')

plt.subplot(152)
df.boxplot('x.texture_se')

plt.subplot(153)
df.boxplot('x.perimeter_se')

plt.subplot(154)
df.boxplot('x.area_se')

plt.subplot(155)
df.boxplot('x.smoothness_se')

plt.show()

# %%
'''
Conclusions ->
1. radius_se has more than 20 outliers on the higher side
2. texture_se has more than 15 outliers on the higher side
3. perimeter_se has more than 20 outliers on the higher side
4. area_se has has more than 20 outliers on the higher side
5. smoothness_se has more than 15 outliers on the higher side
'''
# Out:
# '\nConclusions ->\n1. radius_se has more than 20 outliers on the higher side\n2. texture_se has more than 15 outliers on the higher side\n3. perimeter_se has more than 20 outliers on the higher side\n4. area_se has has more than 20 outliers on the higher side\n5. smoothness_se has more than 15 outliers on the higher side\n'

# %%
# Box plot
plt.figure(figsize = (18, 5))

plt.subplot(151)
df.boxplot('x.compactness_se')

plt.subplot(152)
df.boxplot('x.concavity_se')

plt.subplot(153)
df.boxplot('x.concave_pts_se')

plt.subplot(154)
df.boxplot('x.symmetry_se')

plt.subplot(155)
df.boxplot('x.fractal_dim_se')

plt.show()

# %%
'''
Conclusions ->
1. compactness_se has more than 20 outliers on the higher side
2. concavity_se has more than 10 outliers on the higher side
3. concave_pts_se has more than 10 outliers on the higher side
4. symmetry_se have more than 15 outliers on the higher side
5. fractal_dim_se has more than 15 outliers on the higher side
'''
# Out:
# '\nConclusions ->\n1. compactness_se has more than 20 outliers on the higher side\n2. concavity_se has more than 10 outliers on the higher side\n3. concave_pts_se has more than 10 outliers on the higher side\n4. symmetry_se have more than 15 outliers on the higher side\n5. fractal_dim_se has more than 15 outliers on the higher side\n'

# %%
# Box plot
plt.figure(figsize = (18, 5))

plt.subplot(151)
df.boxplot('x.radius_worst')

plt.subplot(152)
df.boxplot('x.texture_worst')

plt.subplot(153)
df.boxplot('x.perimeter_worst')

plt.subplot(154)
df.boxplot('x.area_worst')

plt.subplot(155)
df.boxplot('x.smoothness_worst')

plt.show()

# %%
'''
Conclusions ->
1. radius_worst has more than 10 outliers on the higher side
2. texture_worst has 5 outliers on the higher side
3. perimeter_worst has 10 outliers on the higher side
4. area_worst has more than 20 outliers on the higher side
5. smoothness_worst have 5 outliers on the higher side and one outlier on the lower side
'''
# Out:
# '\nConclusions ->\n1. radius_worst has more than 10 outliers on the higher side\n2. texture_worst has 5 outliers on the higher side\n3. perimeter_worst has 10 outliers on the higher side\n4. area_worst has more than 20 outliers on the higher side\n5. smoothness_worst have 5 outliers on the higher side and one outlier on the lower side\n'

# %%
# Box plot
plt.figure(figsize = (18, 5))

plt.subplot(151)
df.boxplot('x.compactness_worst')

plt.subplot(152)
df.boxplot('x.concavity_worst')

plt.subplot(153)
df.boxplot('x.concave_pts_worst')

plt.subplot(154)
df.boxplot('x.symmetry_worst')

plt.subplot(155)
df.boxplot('x.fractal_dim_worst')

plt.show()

# %%
'''
Conclusions ->
1. compactness_worst has more than 10 outliers on the higher side
2. concavity_worst has more than 10 outliers on the higher side
3. concave_pts_worst has no outliers
4. symmetry_worst have more than 10 outliers on the higher side
5. fractal_dim_worst has more than 10 outliers on the higher side
'''
# Out:
# '\nConclusions ->\n1. compactness_worst has more than 10 outliers on the higher side\n2. concavity_worst has more than 10 outliers on the higher side\n3. concave_pts_worst has no outliers\n4. symmetry_worst have more than 10 outliers on the higher side\n5. fractal_dim_worst has more than 10 outliers on the higher side\n'

# %%
# Analytical Analysis
df.describe()
# Out:
#        x.radius_mean  x.texture_mean  x.perimeter_mean  x.area_mean  \
# count     569.000000      569.000000        569.000000   569.000000
# mean       14.127292       19.289649         91.969033   654.889104
# std         3.524049        4.301036         24.298981   351.914129
# min         6.981000        9.710000         43.790000   143.500000
# 25%        11.700000       16.170000         75.170000   420.300000
# 50%        13.370000       18.840000         86.240000   551.100000
# 75%        15.780000       21.800000        104.100000   782.700000
# max        28.110000       39.280000        188.500000  2501.000000
#
#        x.smoothness_mean  x.compactness_mean  x.concavity_mean  \
# count         569.000000          569.000000        569.000000
# mean            0.096360            0.104341          0.088799
# std             0.014064            0.052813          0.079720
# min             0.052630            0.019380          0.000000
# ...

# %%
'''
Conclusions ->
 1. For radius_mean, mean is greater than median, which tells that its distribution is right skewed.
 2. For texture_mean, mean is greater than median, which tells that its distribution is right skewed.
 3. For perimeter_mean, mean is greater than median, which tells that its distribution is right skewed.
 4. For area_mean, mean is greater than median, which tells that its distribution is right skewed.
 5. For smoothness_mean, mean is greater than median, which tells that its distribution is right skewed.
 6. For compactness_mean, mean is greater than median, which tells that its distribution is right skewed.
 7. For concavity_mean, mean is greater than median, which tells that its distribution is right skewed.
 8. For concave_pts_mean, mean is greater than median, which tells that its distribution is right skewed.
 9. For symmetry_mean, mean is greater than median, which tells that its distribution is right skewed.
10. For fractal_dim_mean, mean is greater than median, which tells that its distribution is right skewed.
11. For radius_se, mean is greater than median, which tells that its distribution is right skewed.
12. For texture_se, mean is greater than median, which tells that its distribution is right skewed.
13. For perimeter_se, mean is greater than median, which tells that its distribution is right skewed.
14. For area_se, mean is greater than median, which tells that its distribution is right skewed.
15. For smoothness_se, mean is greater than median, which tells that its distribution is right skewed.
16. For compactness_se, mean is greater than median, which tells that its distribution is right skewed.
17. For concavity_se, mean is greater than median, which tells that its distribution is right skewed.
18. For concave_pts_se, mean is greater than median, which tells that its distribution is right skewed.
19. For symmetry_se, mean is greater than median, which tells that its distribution is right skewed.
20. For fractal_dim_se, mean is greater than median, which tells that its distribution is right skewed.
21. For radius_worst, mean is greater than median, which tells that its distribution is right skewed.
22. For texture_worst, mean is greater than median, which tells that its distribution is right skewed.
23. For perimeter_worst, mean is greater than median, which tells that its distribution is right skewed.
24. For area_worst, mean is greater than median, which tells that its distribution is right skewed.
25. For smoothness_worst, mean is greater than median, which tells that its distribution is right skewed.
26. For compactness_worst, mean is greater than median, which tells that its distribution is right skewed.
27. For concavity_worst, mean is greater than median, which tells that its distribution is right skewed.
28. For concave_pts_worst, mean is greater than median, which tells that its distribution is right skewed.
29. For symmetry_worst, mean is greater than median, which tells that its distribution is right skewed.
30. For fractal_dim_worst, mean is greater than median, which tells that its distribution is right skewed.
'''
# Out:
# '\nConclusions ->\n 1. For radius_mean, mean is greater than median, which tells that its distribution is right skewed.\n 2. For texture_mean, mean is greater than median, which tells that its distribution is right skewed.\n 3. For perimeter_mean, mean is greater than median, which tells that its distribution is right skewed.\n 4. For area_mean, mean is greater than median, which tells that its distribution is right skewed.\n 5. For smoothness_mean, mean is greater than median, which tells that its distribution is right skewed.\n 6. For compactness_mean, mean is greater than median, which tells that its distribution is right skewed.\n 7. For concavity_mean, mean is greater than median, which tells that its distribution is right skewed.\n 8. For concave_pts_mean, mean is greater than median, which tells that its distribution is right skewed.\n 9. For symmetry_mean, mean is greater than median, which tells that its distribution is right skewed.\n10. For fractal_dim_mean, mean is greate
# ...

# %%
# Distribution plot
plt.figure(figsize = (30, 5))

plt.subplot(151)
sns.distplot(df['x.radius_mean'])

plt.subplot(152)
sns.distplot(df['x.texture_mean'])

plt.subplot(153)
sns.distplot(df['x.perimeter_mean'])

plt.subplot(154)
sns.distplot(df['x.area_mean'])

plt.subplot(155)
sns.distplot(df['x.smoothness_mean'])

plt.show()

# %%
# Distribution plot
plt.figure(figsize = (30, 5))

plt.subplot(151)
sns.distplot(df['x.compactness_mean'])

plt.subplot(152)
sns.distplot(df['x.concavity_mean'])

plt.subplot(153)
sns.distplot(df['x.concave_pts_mean'])

plt.subplot(154)
sns.distplot(df['x.symmetry_mean'])

plt.subplot(155)
sns.distplot(df['x.fractal_dim_mean'])

plt.show()

# %%
# Distribution plot
plt.figure(figsize = (30, 5))

plt.subplot(151)
sns.distplot(df['x.radius_se'])

plt.subplot(152)
sns.distplot(df['x.texture_se'])

plt.subplot(153)
sns.distplot(df['x.perimeter_se'])

plt.subplot(154)
sns.distplot(df['x.area_se'])

plt.subplot(155)
sns.distplot(df['x.smoothness_se'])

plt.show()

# %%
# Distribution plot
plt.figure(figsize = (30, 5))

plt.subplot(151)
sns.distplot(df['x.compactness_se'])

plt.subplot(152)
sns.distplot(df['x.concavity_se'])

plt.subplot(153)
sns.distplot(df['x.concave_pts_se'])

plt.subplot(154)
sns.distplot(df['x.symmetry_se'])

plt.subplot(155)
sns.distplot(df['x.fractal_dim_se'])

plt.show()

# %%
# Distribution plot
plt.figure(figsize = (30, 5))

plt.subplot(151)
sns.distplot(df['x.radius_worst'])

plt.subplot(152)
sns.distplot(df['x.texture_worst'])

plt.subplot(153)
sns.distplot(df['x.perimeter_worst'])

plt.subplot(154)
sns.distplot(df['x.area_worst'])

plt.subplot(155)
sns.distplot(df['x.smoothness_worst'])

plt.show()

# %%
# Distribution plot
plt.figure(figsize = (30, 5))

plt.subplot(151)
sns.distplot(df['x.compactness_worst'])

plt.subplot(152)
sns.distplot(df['x.concavity_worst'])

plt.subplot(153)
sns.distplot(df['x.concave_pts_worst'])

plt.subplot(154)
sns.distplot(df['x.symmetry_worst'])

plt.subplot(155)
sns.distplot(df['x.fractal_dim_worst'])

plt.show()

# %%
# Getting an idea about the mean of the measure w.r.t. patients having Cancer or not
df.groupby('y')[['x.radius_mean', 'x.texture_mean', 'x.perimeter_mean', 'x.area_mean']].mean().T.plot(kind='barh', figsize=(15,5))
# Out:
# <Axes: >

# %%
'''
Conclusions ->
1. For Malignant (Cancer), mean of area_mean is more than for Benign (Not Cancer)
2. For Malignant (Cancer), mean of perimeter_mean is more than for Benign (Not Cancer)
3. For Malignant (Cancer), mean of texture_mean is more than for Benign (Not Cancer)
4. For Malignant (Cancer), mean of radius_mean is more than for Benign (Not Cancer)
'''
# Out:
# '\nConclusions ->\n1. For Malignant (Cancer), mean of area_mean is more than for Benign (Not Cancer)\n2. For Malignant (Cancer), mean of perimeter_mean is more than for Benign (Not Cancer)\n3. For Malignant (Cancer), mean of texture_mean is more than for Benign (Not Cancer)\n4. For Malignant (Cancer), mean of radius_mean is more than for Benign (Not Cancer)\n'

# %%
# Getting an idea about the mean of the measure w.r.t. patients having Cancer or not
df.groupby('y')[['x.smoothness_mean', 'x.compactness_mean', 'x.concavity_mean', 'x.concave_pts_mean', 'x.symmetry_mean', 'x.fractal_dim_mean']].mean().T.plot(kind='barh', figsize=(15,8))
# Out:
# <Axes: >

# %%
'''
Conclusions ->
1. For Malignant (Cancer) and Benign (Not Cancer), mean of fractal_dim_mean is almost same.
2. For Malignant (Cancer), mean of symmetry_mean is more than for Benign (Not Cancer)
3. For Malignant (Cancer), mean of concave_pts_mean is more than for Benign (Not Cancer)
4. For Malignant (Cancer), mean of concavity_mean is more than for Benign (Not Cancer)
5. For Malignant (Cancer), mean of compactness_mean is more than for Benign (Not Cancer)
6. For Malignant (Cancer), mean of smoothness_mean is more than for Benign (Not Cancer)
'''
# Out:
# '\nConclusions ->\n1. For Malignant (Cancer) and Benign (Not Cancer), mean of fractal_dim_mean is almost same.\n2. For Malignant (Cancer), mean of symmetry_mean is more than for Benign (Not Cancer)\n3. For Malignant (Cancer), mean of concave_pts_mean is more than for Benign (Not Cancer)\n4. For Malignant (Cancer), mean of concavity_mean is more than for Benign (Not Cancer)\n5. For Malignant (Cancer), mean of compactness_mean is more than for Benign (Not Cancer)\n6. For Malignant (Cancer), mean of smoothness_mean is more than for Benign (Not Cancer)\n'

# %%
# Getting an idea about the mean of the measure w.r.t. patients having Cancer or not
df.groupby('y')[['x.radius_se', 'x.texture_se', 'x.perimeter_se', 'x.area_se']].mean().T.plot(kind='barh', figsize=(15,5))
# Out:
# <Axes: >

# %%
'''
Conclusions ->
1. For Malignant (Cancer), mean of area_se is more than for Benign (Not Cancer)
2. For Malignant (Cancer), mean of perimeter_se is more than for Benign (Not Cancer)
3. For Malignant (Cancer), mean of texture_se is same as for Benign (Not Cancer)
4. For Malignant (Cancer), mean of radius_se is more than for Benign (Not Cancer)
'''
# Out:
# '\nConclusions ->\n1. For Malignant (Cancer), mean of area_se is more than for Benign (Not Cancer)\n2. For Malignant (Cancer), mean of perimeter_se is more than for Benign (Not Cancer)\n3. For Malignant (Cancer), mean of texture_se is same as for Benign (Not Cancer)\n4. For Malignant (Cancer), mean of radius_se is more than for Benign (Not Cancer)\n'

# %%
# Getting an idea about the mean of the measure w.r.t. patients having Cancer or not
df.groupby('y')[['x.smoothness_se', 'x.compactness_se', 'x.concavity_se', 'x.concave_pts_se', 'x.symmetry_se', 'x.fractal_dim_se']].mean().T.plot(kind='barh', figsize=(15,8))
# Out:
# <Axes: >

# %%
'''
Conclusions ->
1. For Malignant (Cancer), mean of fractal_dim_se is more than Benign (Not Cancer).
2. For Malignant (Cancer), mean of symmetry_se is lesser than for Benign (Not Cancer)
3. For Malignant (Cancer), mean of concave_pts_se is more than for Benign (Not Cancer)
4. For Malignant (Cancer), mean of concavity_se is more than for Benign (Not Cancer)
5. For Malignant (Cancer), mean of compactness_se is more than for Benign (Not Cancer)
6. For Malignant (Cancer), mean of smoothness_se is lesser than for Benign (Not Cancer)
'''
# Out:
# '\nConclusions ->\n1. For Malignant (Cancer), mean of fractal_dim_se is more than Benign (Not Cancer).\n2. For Malignant (Cancer), mean of symmetry_se is lesser than for Benign (Not Cancer)\n3. For Malignant (Cancer), mean of concave_pts_se is more than for Benign (Not Cancer)\n4. For Malignant (Cancer), mean of concavity_se is more than for Benign (Not Cancer)\n5. For Malignant (Cancer), mean of compactness_se is more than for Benign (Not Cancer)\n6. For Malignant (Cancer), mean of smoothness_se is lesser than for Benign (Not Cancer)\n'

# %%
# Getting an idea about the mean of the measure w.r.t. patients having Cancer or not
df.groupby('y')[['x.radius_worst', 'x.texture_worst', 'x.perimeter_worst', 'x.area_worst']].mean().T.plot(kind='barh', figsize=(15,5))
# Out:
# <Axes: >

# %%
'''
Conclusions ->
1. For Malignant (Cancer), mean of area_worst is more than for Benign (Not Cancer)
2. For Malignant (Cancer), mean of perimeter_worst is more than for Benign (Not Cancer)
3. For Malignant (Cancer), mean of texture_worst is more than for Benign (Not Cancer)
4. For Malignant (Cancer), mean of radius_worst is more than for Benign (Not Cancer)
'''
# Out:
# '\nConclusions ->\n1. For Malignant (Cancer), mean of area_worst is more than for Benign (Not Cancer)\n2. For Malignant (Cancer), mean of perimeter_worst is more than for Benign (Not Cancer)\n3. For Malignant (Cancer), mean of texture_worst is more than for Benign (Not Cancer)\n4. For Malignant (Cancer), mean of radius_worst is more than for Benign (Not Cancer)\n'

# %%
# Getting an idea about the mean of the measure w.r.t. patients having Cancer or not
df.groupby('y')[['x.smoothness_worst', 'x.compactness_worst', 'x.concavity_worst', 'x.concave_pts_worst', 'x.symmetry_worst', 'x.fractal_dim_worst']].mean().T.plot(kind='barh', figsize=(15,8))
# Out:
# <Axes: >

# %%
'''
Conclusions ->
1. For Malignant (Cancer), mean of fractal_dim_worst is more than for Benign (Not Cancer)
2. For Malignant (Cancer), mean of symmetry_worst is more than for Benign (Not Cancer)
3. For Malignant (Cancer), mean of concave_pts_worst is more than for Benign (Not Cancer)
4. For Malignant (Cancer), mean of concavity_worst is more than for Benign (Not Cancer)
5. For Malignant (Cancer), mean of compactness_worst is more than for Benign (Not Cancer)
6. For Malignant (Cancer), mean of smoothness_worst is more than for Benign (Not Cancer)
'''
# Out:
# '\nConclusions ->\n1. For Malignant (Cancer), mean of fractal_dim_worst is more than for Benign (Not Cancer)\n2. For Malignant (Cancer), mean of symmetry_worst is more than for Benign (Not Cancer)\n3. For Malignant (Cancer), mean of concave_pts_worst is more than for Benign (Not Cancer)\n4. For Malignant (Cancer), mean of concavity_worst is more than for Benign (Not Cancer)\n5. For Malignant (Cancer), mean of compactness_worst is more than for Benign (Not Cancer)\n6. For Malignant (Cancer), mean of smoothness_worst is more than for Benign (Not Cancer)\n'

# %%
# Relationship plot between radius_mean, radius_se w.r.t. y
plt.figure(figsize = (15, 5))
sns.relplot(x = 'x.radius_mean', y = 'x.radius_se', hue = 'y', data = df)

plt.show()

# %%
'''
Conclusions ->
1. The maximum distribution of Malignant, for radius_mean, is found between the range of 12.5 and 22
2. The maximum distribution of Malignant, for radius_se, is found between the range of 0.2 and 1.4
3. The maximum distribution of Benign, for radius_mean, is found between the range of 5 and 17
4. The maximum distribution of Benign, for radius_se, is found between the range of 0.1 and 0.6
'''
# Out:
# '\nConclusions ->\n1. The maximum distribution of Malignant, for radius_mean, is found between the range of 12.5 and 22\n2. The maximum distribution of Malignant, for radius_se, is found between the range of 0.2 and 1.4\n3. The maximum distribution of Benign, for radius_mean, is found between the range of 5 and 17\n4. The maximum distribution of Benign, for radius_se, is found between the range of 0.1 and 0.6\n'

# %%
# Relationship plot between radius_mean and radius_worst w.r.t. y
plt.figure(figsize = (15, 5))
sns.relplot(x = 'x.radius_mean', y = 'x.radius_worst', hue = 'y', data = df)

plt.show()

# %%
'''
Conclusions ->
1. The maximum distribution of Malignant, for radius_mean, is found between the range of 12.5 and 22
2. The maximum distribution of Malignant, for radius_worst, is found between the range of 12.5 and 26
3. The maximum distribution of Benign, for radius_mean, is found between the range of 5 and 17
4. The maximum distribution of Benign, for radius_worst, is found between the range of 8 and 17.5
'''
# Out:
# '\nConclusions ->\n1. The maximum distribution of Malignant, for radius_mean, is found between the range of 12.5 and 22\n2. The maximum distribution of Malignant, for radius_worst, is found between the range of 12.5 and 26\n3. The maximum distribution of Benign, for radius_mean, is found between the range of 5 and 17\n4. The maximum distribution of Benign, for radius_worst, is found between the range of 8 and 17.5\n'

# %%
# Relationship plot between texture_mean, texture_se w.r.t. y
plt.figure(figsize = (15, 5))
sns.relplot(x = 'x.texture_mean', y = 'x.texture_se', hue = 'y', data = df)

plt.show()

# %%
'''
Conclusions ->
1. The maximum distribution of Malignant, for texture_mean, is found between the range of 16 and 29
2. The maximum distribution of Malignant, for texture_se, is found between the range of 0.3 and 2.1
3. The maximum distribution of Benign, for texture_mean, is found between the range of 10 and 26
4. The maximum distribution of Benign, for texture_se, is found between the range of 0.2 and 2.4
'''
# Out:
# '\nConclusions ->\n1. The maximum distribution of Malignant, for texture_mean, is found between the range of 16 and 29\n2. The maximum distribution of Malignant, for texture_se, is found between the range of 0.3 and 2.1\n3. The maximum distribution of Benign, for texture_mean, is found between the range of 10 and 26\n4. The maximum distribution of Benign, for texture_se, is found between the range of 0.2 and 2.4\n'

# %%
# Relationship plot between texture_mean and texture_worst w.r.t. y
plt.figure(figsize = (15, 5))
sns.relplot(x = 'x.texture_mean', y = 'x.texture_worst', hue = 'y', data = df)

plt.show()

# %%
'''
Conclusions ->
1. The maximum distribution of Malignant, for texture_mean, is found between the range of 16 and 29
2. The maximum distribution of Malignant, for texture_worst, is found between the range of 20 and 37.5
3. The maximum distribution of Benign, for texture_mean, is found between the range of 10 and 26
4. The maximum distribution of Benign, for texture_worst, is found between the range of 10 and 32.5
'''
# Out:
# '\nConclusions ->\n1. The maximum distribution of Malignant, for texture_mean, is found between the range of 16 and 29\n2. The maximum distribution of Malignant, for texture_worst, is found between the range of 20 and 37.5\n3. The maximum distribution of Benign, for texture_mean, is found between the range of 10 and 26\n4. The maximum distribution of Benign, for texture_worst, is found between the range of 10 and 32.5\n'

# %%
# Relationship plot between perimeter_mean, perimeter_se w.r.t. y
plt.figure(figsize = (15, 5))
sns.relplot(x = 'x.perimeter_mean', y = 'x.perimeter_se', hue = 'y', data = df)

plt.show()

# %%
'''
Conclusions ->
1. The maximum distribution of Malignant, for perimeter_mean, is found between the range of 75 and 140
2. The maximum distribution of Malignant, for perimeter_se, is found between the range of 2 and 7
3. The maximum distribution of Benign, for perimeter_mean, is found between the range of 50 and 100
4. The maximum distribution of Benign, for perimeter_se, is found between the range of 1 and 4
'''
# Out:
# '\nConclusions ->\n1. The maximum distribution of Malignant, for perimeter_mean, is found between the range of 75 and 140\n2. The maximum distribution of Malignant, for perimeter_se, is found between the range of 2 and 7\n3. The maximum distribution of Benign, for perimeter_mean, is found between the range of 50 and 100\n4. The maximum distribution of Benign, for perimeter_se, is found between the range of 1 and 4\n'

# %%
# Relationship plot between perimeter_mean and perimeter_worst w.r.t. y
plt.figure(figsize = (15, 5))
sns.relplot(x = 'x.perimeter_mean', y = 'x.perimeter_worst', hue = 'y', data = df)

plt.show()

# %%
'''
Conclusions ->
1. The maximum distribution of Malignant, for perimeter_mean, is found between the range of 75 and 140
2. The maximum distribution of Malignant, for perimeter_worst, is found between the range of 12.5 and 26
3. The maximum distribution of Benign, for perimeter_mean, is found between the range of 55 and 118
4. The maximum distribution of Benign, for perimeter_worst, is found between the range of 8 and 17.5
'''
# Out:
# '\nConclusions ->\n1. The maximum distribution of Malignant, for perimeter_mean, is found between the range of 75 and 140\n2. The maximum distribution of Malignant, for perimeter_worst, is found between the range of 12.5 and 26\n3. The maximum distribution of Benign, for perimeter_mean, is found between the range of 55 and 118\n4. The maximum distribution of Benign, for perimeter_worst, is found between the range of 8 and 17.5\n'

# %%
# Relationship plot between area_mean, area_se w.r.t. y
plt.figure(figsize = (15, 5))
sns.relplot(x = 'x.area_mean', y = 'x.area_se', hue = 'y', data = df)

plt.show()

# %%
'''
Conclusions ->
1. The maximum distribution of Malignant, for area_mean, is found between the range of 260 and 1300
2. The maximum distribution of Malignant, for area_se, is found between the range of 20 and 130
3. The maximum distribution of Benign, for area_mean, is found between the range of 140 and 850
4. The maximum distribution of Benign, for area_se, is found between the range of 10 and 60
'''
# Out:
# '\nConclusions ->\n1. The maximum distribution of Malignant, for area_mean, is found between the range of 260 and 1300\n2. The maximum distribution of Malignant, for area_se, is found between the range of 20 and 130\n3. The maximum distribution of Benign, for area_mean, is found between the range of 140 and 850\n4. The maximum distribution of Benign, for area_se, is found between the range of 10 and 60\n'

# %%
# Relationship plot between area_mean and area_worst w.r.t. y
plt.figure(figsize = (15, 5))
sns.relplot(x = 'x.area_mean', y = 'x.area_worst', hue = 'y', data = df)

plt.show()

# %%
'''
Conclusions ->
1. The maximum distribution of Malignant, for area_mean, is found between the range of 260 and 1300
2. The maximum distribution of Malignant, for area_worst, is found between the range of 500 and 2100
3. The maximum distribution of Benign, for area_mean, is found between the range of 140 and 850
4. The maximum distribution of Benign, for area_worst, is found between the range of 185 and 1100
'''
# Out:
# '\nConclusions ->\n1. The maximum distribution of Malignant, for area_mean, is found between the range of 260 and 1300\n2. The maximum distribution of Malignant, for area_worst, is found between the range of 500 and 2100\n3. The maximum distribution of Benign, for area_mean, is found between the range of 140 and 850\n4. The maximum distribution of Benign, for area_worst, is found between the range of 185 and 1100\n'

# %%
# Relationship plot between smoothness_mean, smoothness_se w.r.t. y
plt.figure(figsize = (15, 5))
sns.relplot(x = 'x.smoothness_mean', y = 'x.smoothness_se', hue = 'y', data = df)

plt.show()

# %%
'''
Conclusions ->
1. The maximum distribution of Malignant, for smoothness_mean, is found between the range of 0.08 and 0.12
2. The maximum distribution of Malignant, for smoothness_se, is found between the range of 0.003 and 0.0115
3. The maximum distribution of Benign, for smoothness_mean, is found between the range of 0.065 and 0.115
4. The maximum distribution of Benign, for smoothness_se, is found between the range of 0.0035 and 0.015
'''
# Out:
# '\nConclusions ->\n1. The maximum distribution of Malignant, for smoothness_mean, is found between the range of 0.08 and 0.12\n2. The maximum distribution of Malignant, for smoothness_se, is found between the range of 0.003 and 0.0115\n3. The maximum distribution of Benign, for smoothness_mean, is found between the range of 0.065 and 0.115\n4. The maximum distribution of Benign, for smoothness_se, is found between the range of 0.0035 and 0.015\n'

# %%
# Relationship plot between smoothness_mean and smoothness_worst w.r.t. y
plt.figure(figsize = (15, 5))
sns.relplot(x = 'x.smoothness_mean', y = 'x.smoothness_worst', hue = 'y', data = df)

plt.show()

# %%
'''
Conclusions ->
1. The maximum distribution of Malignant, for smoothness_mean, is found between the range of 0.08 and 0.12
2. The maximum distribution of Malignant, for smoothness_worst, is found between the range of 0.11 and 0.17
3. The maximum distribution of Benign, for smoothness_mean, is found between the range of 0.065 and 0.115
4. The maximum distribution of Benign, for smoothness_worst, is found between the range of 0.085 and 0.155
'''
# Out:
# '\nConclusions ->\n1. The maximum distribution of Malignant, for smoothness_mean, is found between the range of 0.08 and 0.12\n2. The maximum distribution of Malignant, for smoothness_worst, is found between the range of 0.11 and 0.17\n3. The maximum distribution of Benign, for smoothness_mean, is found between the range of 0.065 and 0.115\n4. The maximum distribution of Benign, for smoothness_worst, is found between the range of 0.085 and 0.155\n'

# %%
# Relationship plot between compactness_mean, compactness_se w.r.t. y
plt.figure(figsize = (15, 5))
sns.relplot(x = 'x.compactness_mean', y = 'x.compactness_se', hue = 'y', data = df)

plt.show()

# %%
'''
Conclusions ->
1. The maximum distribution of Malignant, for compactness_mean, is found between the range of 0.04 and 0.18
2. The maximum distribution of Malignant, for compactness_se, is found between the range of 0.0008 and 0.044
3. The maximum distribution of Benign, for compactness_mean, is found between the range of 0.01 and 0.14
4. The maximum distribution of Benign, for compactness_se, is found between the range of 0.0001 and 0.04
'''
# Out:
# '\nConclusions ->\n1. The maximum distribution of Malignant, for compactness_mean, is found between the range of 12.5 and 22\n2. The maximum distribution of Malignant, for compactness_se, is found between the range of 0.2 and 1.4\n3. The maximum distribution of Benign, for compactness_mean, is found between the range of 5 and 17\n4. The maximum distribution of Benign, for compactness_se, is found between the range of 0.1 and 0.6\n'

# %%
# Relationship plot between compactness_mean and compactness_worst w.r.t. y
plt.figure(figsize = (15, 5))
sns.relplot(x = 'x.compactness_mean', y = 'x.compactness_worst', hue = 'y', data = df)

plt.show()

# %%
'''
Conclusions ->
1. The maximum distribution of Malignant, for compactness_mean, is found between the range of 0.04 and 0.18
2. The maximum distribution of Malignant, for compactness_worst, is found between the range of 0.14 and 0.5
3. The maximum distribution of Benign, for compactness_mean, is found between the range of 0.01 and 0.14
4. The maximum distribution of Benign, for compactness_worst, is found between the range of 0.03 and 0.35
'''
# Out:
# '\nConclusions ->\n1. The maximum distribution of Malignant, for compactness_mean, is found between the range of 12.5 and 22\n2. The maximum distribution of Malignant, for compactness_worst, is found between the range of 12.5 and 26\n3. The maximum distribution of Benign, for compactness_mean, is found between the range of 5 and 17\n4. The maximum distribution of Benign, for compactness_worst, is found between the range of 8 and 17.5\n'

# %%
# Relationship plot between concavity_mean, concavity_se w.r.t. y
plt.figure(figsize = (15, 5))
sns.relplot(x = 'x.concavity_mean', y = 'x.concavity_se', hue = 'y', data = df)

plt.show()

# %%
'''
Conclusions ->
1. The maximum distribution of Malignant, for concavity_mean, is found between the range of 0.015 and 0.235
2. The maximum distribution of Malignant, for concavity_se, is found between the range of 0.0175 and 0.054
3. The maximum distribution of Benign, for concavity_mean, is found between the range of 0 and 0.1
4. The maximum distribution of Benign, for concavity_se, is found between the range of 0 and 0.065
'''
# Out:
# '\nConclusions ->\n1. The maximum distribution of Malignant, for concavity_mean, is found between the range of 12.5 and 22\n2. The maximum distribution of Malignant, for concavity_se, is found between the range of 0.2 and 1.4\n3. The maximum distribution of Benign, for concavity_mean, is found between the range of 5 and 17\n4. The maximum distribution of Benign, for concavity_se, is found between the range of 0.1 and 0.6\n'

# %%
# Relationship plot between concavity_mean and concavity_worst w.r.t. y
plt.figure(figsize = (15, 5))
sns.relplot(x = 'x.concavity_mean', y = 'x.concavity_worst', hue = 'y', data = df)

plt.show()

# %%
'''
Conclusions ->
1. The maximum distribution of Malignant, for concavity_mean, is found between the range of 0.015 and 0.235
2. The maximum distribution of Malignant, for concavity_worst, is found between the range of 0.2 and 0.6
3. The maximum distribution of Benign, for concavity_mean, is found between the range of 0 and 0.1
4. The maximum distribution of Benign, for concavity_worst, is found between the range of 0 and 0.4
'''
# Out:
# '\nConclusions ->\n1. The maximum distribution of Malignant, for concavity_mean, is found between the range of 12.5 and 22\n2. The maximum distribution of Malignant, for concavity_worst, is found between the range of 12.5 and 26\n3. The maximum distribution of Benign, for concavity_mean, is found between the range of 5 and 17\n4. The maximum distribution of Benign, for concavity_worst, is found between the range of 8 and 17.5\n'

# %%
# Relationship plot between concave_pts_mean, concave_pts_se w.r.t. y
plt.figure(figsize = (15, 5))
sns.relplot(x = 'x.concave_pts_mean', y = 'x.concave_pts_se', hue = 'y', data = df)

plt.show()

# %%
'''
Conclusions ->
1. The maximum distribution of Malignant, for concave_pts_mean, is found between the range of 0.02 and 0.1175
2. The maximum distribution of Malignant, for concave_pts_se, is found between the range of 0.006 and 0.02
3. The maximum distribution of Benign, for concave_pts_mean, is found between the range of 0 and 0.07
4. The maximum distribution of Benign, for concave_pts_se, is found between the range of 0 and 0.018
'''

# %%
# Relationship plot between concave_pts_mean and concave_pts_worst w.r.t. y
plt.figure(figsize = (15, 5))
sns.relplot(x = 'x.concave_pts_mean', y = 'x.concave_pts_worst', hue = 'y', data = df)

plt.show()

# %%
'''
Conclusions ->
1. The maximum distribution of Malignant, for concave_pts_mean, is found between the range of 0.02 and 0.1175
2. The maximum distribution of Malignant, for concave_pts_worst, is found between the range of 0.112 and 0.25
3. The maximum distribution of Benign, for concave_pts_mean, is found between the range of 0 and 0.07
4. The maximum distribution of Benign, for concave_pts_worst, is found between the range of 0 and 0.15
'''

# %%
# Relationship plot between symmetry_mean, symmetry_se w.r.t. y
plt.figure(figsize = (15, 5))
sns.relplot(x = 'x.symmetry_mean', y = 'x.symmetry_se', hue = 'y', data = df)

plt.show()

# %%
'''
Conclusions ->
1. The maximum distribution of Malignant, for symmetry_mean, is found between the range of 0.135 and 0.225
2. The maximum distribution of Malignant, for symmetry_se, is found between the range of 0.01 and 0.024
3. The maximum distribution of Benign, for symmetry_mean, is found between the range of 0.13 and 0.212
4. The maximum distribution of Benign, for symmetry_se, is found between the range of 0.01 and 0.023
'''

# %%
# Relationship plot between symmetry_mean and symmetry_worst w.r.t. y
plt.figure(figsize = (15, 5))
sns.relplot(x = 'x.symmetry_mean', y = 'x.symmetry_worst', hue = 'y', data = df)

plt.show()

# %%
'''
Conclusions ->
1. The maximum distribution of Malignant, for symmetry_mean, is found between the range of 0.135 and 0.225
2. The maximum distribution of Malignant, for symmetry_worst, is found between the range of 0.225 and 0.38
3. The maximum distribution of Benign, for symmetry_mean, is found between the range of 0.13 and 0.212
4. The maximum distribution of Benign, for symmetry_worst, is found between the range of 0.15 and 0.35
'''

# %%
# Relationship plot between fractal_dim_mean, fractal_dim_se w.r.t. y
plt.figure(figsize = (15, 5))
sns.relplot(x = 'x.fractal_dim_mean', y = 'x.fractal_dim_se', hue = 'y', data = df)

plt.show()

# %%
'''
Conclusions ->
1. The maximum distribution of Malignant, for fractal_dim_mean, is found between the range of 0.04 and 0.075
2. The maximum distribution of Malignant, for fractal_dim_se, is found between the range of 0.0017 and 0.007
3. The maximum distribution of Benign, for fractal_dim_mean, is found between the range of 0.052 and 0.073
4. The maximum distribution of Benign, for fractal_dim_se, is found between the range of 0.1 and 0.00525
'''

# %%
# Relationship plot between fractal_dim_mean and fractal_dim_worst w.r.t. y
plt.figure(figsize = (15, 5))
sns.relplot(x = 'x.fractal_dim_mean', y = 'x.fractal_dim_worst', hue = 'y', data = df)

plt.show()

# %%
'''
Conclusions ->
1. The maximum distribution of Malignant, for fractal_dim_mean, is found between the range of 0.04 and 0.074
2. The maximum distribution of Malignant, for fractal_dim_worst, is found between the range of 0.05 and 0.11
3. The maximum distribution of Benign, for fractal_dim_mean, is found between the range of 0.052 and 0.073
4. The maximum distribution of Benign, for fractal_dim_worst, is found between the range of 0.03 and 0.10
'''
